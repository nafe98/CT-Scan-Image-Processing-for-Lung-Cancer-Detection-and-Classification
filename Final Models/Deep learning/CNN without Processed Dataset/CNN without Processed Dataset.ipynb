# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

import numpy as np
import matplotlib.pylab as plt

# %%
class_names = ['Benign cases', 'Malignant cases', 'Normal cases']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
  
    datasets = ['Train', 'Test']
    output = []
    
    
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#  26%|█████████████████████▏                                                           | 22/84 [00:00<00:00, 211.35it/s]
# Loading Train
# 100%|█████████████████████████████████████████████████████████████████████████████████| 84/84 [00:00<00:00, 215.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 393/393 [00:01<00:00, 218.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 291/291 [00:01<00:00, 203.60it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 206.71it/s]
#   0%|                                                                                          | 0/168 [00:00<?, ?it/s]
# Loading Test
# 100%|███████████████████████████████████████████████████████████████████████████████| 168/168 [00:00<00:00, 234.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 125/125 [00:00<00:00, 212.03it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 768
# Number of testing examples: 329
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=None , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(3, activation=tf.nn.softmax)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 5,319,075
# Trainable params: 5,319,075
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=64, epochs=20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 4s 365ms/step - loss: 1.6194 - accuracy: 0.4886 - val_loss: 0.7986 - val_accuracy: 0.5519
# Epoch 2/20
# 10/10 [==============================] - 3s 345ms/step - loss: 0.6514 - accuracy: 0.7313 - val_loss: 0.5232 - val_accuracy: 0.7922
# Epoch 3/20
# 10/10 [==============================] - 3s 350ms/step - loss: 0.4067 - accuracy: 0.8453 - val_loss: 0.3277 - val_accuracy: 0.8766
# Epoch 4/20
# 10/10 [==============================] - 4s 352ms/step - loss: 0.2051 - accuracy: 0.9577 - val_loss: 0.1868 - val_accuracy: 0.9481
# Epoch 5/20
# 10/10 [==============================] - 4s 354ms/step - loss: 0.1097 - accuracy: 0.9805 - val_loss: 0.0904 - val_accuracy: 0.9740
# Epoch 6/20
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0377 - accuracy: 0.9984 - val_loss: 0.0403 - val_accuracy: 0.9935
# Epoch 7/20
# 10/10 [==============================] - 3s 350ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 8/20
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 9/20
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 10/20
# 10/10 [==============================] - 4s 352ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 11/20
# 10/10 [==============================] - 4s 353ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 12/20
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 13/20
# 10/10 [==============================] - 4s 352ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 14/20
# 10/10 [==============================] - 3s 348ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 15/20
# 10/10 [==============================] - 4s 355ms/step - loss: 9.8464e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 16/20
# 10/10 [==============================] - 4s 351ms/step - loss: 8.5044e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 17/20
# 10/10 [==============================] - 4s 357ms/step - loss: 7.1934e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 18/20
# 10/10 [==============================] - 3s 349ms/step - loss: 6.2467e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 19/20
# 10/10 [==============================] - 4s 354ms/step - loss: 5.3090e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 20/20
# 10/10 [==============================] - 4s 351ms/step - loss: 4.6185e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 11/11 [==============================] - 0s 38ms/step - loss: 1.5042 - accuracy: 0.7052

# %%
test_loss
# Out:
# [1.5041991472244263, 0.7051671743392944]

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
#Print Classification Report
from sklearn.metrics import classification_report
print('Classification Report')

print(classification_report(test_labels,pred_labels))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.39      0.31      0.34        36
#            1       0.76      0.92      0.83       168
#            2       0.69      0.53      0.60       125
#
#     accuracy                           0.71       329
#    macro avg       0.61      0.59      0.59       329
# weighted avg       0.69      0.71      0.69       329

# %%
# Accuracy Curves

plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'],'r',linewidth=3.0)

plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)

plt.xlabel('Epochs ',fontsize=16)

plt.ylabel('Accuracy',fontsize=16)

plt.title('Accuracy Curves for CNN model without Processed Dataset',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves for CNN model without Processed Dataset')

# %%
# Loss Curves

plt.figure(figsize=[8,6])

plt.plot(history.history['loss'],'r',linewidth=3.0)

plt.plot(history.history['val_loss'],'b',linewidth=3.0)

plt.legend(['Training loss', 'Validation Loss'],fontsize=18)

plt.xlabel('Epochs ',fontsize=16)

plt.ylabel('Loss',fontsize=16)

plt.title('Loss Curves for CNN model without Processed Dataset',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves for CNN model without Processed Dataset')
